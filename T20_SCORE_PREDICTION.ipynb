# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_excel("T20_dataset.xlsx")
dataset.head(5)
# Out:
#    Batting Team  Bowling Team        City  Balls Left  Current Score  \
# 0   New Zealand     Sri Lanka     Colombo          51             94
# 1       England  South Africa      Durban           0            204
# 2   New Zealand  South Africa      Durban          23             79
# 3  South Africa   New Zealand  Chattogram          85             39
# 4      Pakistan     Sri Lanka   King City          79             44
#
#    Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  innings  \
# 0          8.173913             9            42                 1        1
# 1         10.200000             3            79                 2        1
# 2          4.886598             2            25                 1        1
# 3          6.685714             8            37                 2        1
# 4          6.439024             8            36                 2        2
#
#    Final_Score
# 0          170
# 1          204
# 2           86
# 3          170
# 4          141

# %%
dataset.isnull().sum()
# Out:
# Batting Team        0
# Bowling Team        0
# City                0
# Balls Left          0
# Current Score       0
# Current Run Rate    0
# Wickets Left        0
# Run_In_Last5        0
# Wickets_In_Last5    0
# innings             0
# Final_Score         0
# dtype: int64

# %%
dataset.describe()
# Out:
#           Balls Left  Current Score  Current Run Rate   Wickets Left  \
# count  131624.000000  131624.000000     131624.000000  131624.000000
# mean       47.629900      91.253563          7.541524       6.651196
# std        26.035401      39.859222          1.766908       2.107944
# min         0.000000       6.000000          1.090909       0.000000
# 25%        26.000000      59.000000          6.322581       5.000000
# 50%        48.000000      87.000000          7.448276       7.000000
# 75%        70.000000     119.000000          8.625000       8.000000
# max        98.000000     278.000000         16.600000      10.000000
#
#         Run_In_Last5  Wickets_In_Last5        innings    Final_Score
# count  131624.000000     131624.000000  131624.000000  131624.000000
# mean       37.814206          1.480080       1.468433     152.533185
# std        11.344096          1.141234       0.499004      32.752668
# min         4.000000          0.000000       1.000000      29.000000
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131624 entries, 0 to 131623
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Batting Team      131624 non-null  object
#  1   Bowling Team      131624 non-null  object
#  2   City              131624 non-null  object
#  3   Balls Left        131624 non-null  int64
#  4   Current Score     131624 non-null  int64
#  5   Current Run Rate  131624 non-null  float64
#  6   Wickets Left      131624 non-null  int64
#  7   Run_In_Last5      131624 non-null  int64
#  8   Wickets_In_Last5  131624 non-null  int64
#  9   innings           131624 non-null  int64
#  10  Final_Score       131624 non-null  int64
# dtypes: float64(1), int64(7), object(3)
# memory usage: 11.0+ MB

# %%
dataset["Batting Team"].value_counts()
# Out:
# Batting Team
# Pakistan        15052
# New Zealand     12865
# India           12818
# Australia       12700
# South Africa    12462
# England         12356
# Sri Lanka       12302
# West Indies     12091
# Bangladesh       9458
# Zimbabwe         7212
# Afghanistan      5062
# Ireland          4873
# Netherlands      2373
# Name: count, dtype: int64

# %%
dataset["Batting Team"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='Batting Team'>

# %%
dataset.corr(numeric_only= True)["Final_Score"]
# Out:
# Balls Left         -0.088130
# Current Score       0.456999
# Current Run Rate    0.705467
# Wickets Left        0.288851
# Run_In_Last5        0.578403
# Wickets_In_Last5   -0.226601
# innings            -0.224086
# Final_Score         1.000000
# Name: Final_Score, dtype: float64

# %%
dataset.head(1)
# Out:
#   Batting Team Bowling Team     City  Balls Left  Current Score  \
# 0  New Zealand    Sri Lanka  Colombo          51             94
#
#    Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  innings  \
# 0          8.173913             9            42                 1        1
#
#    Final_Score
# 0          170

# %%
120 - dataset["Balls Left"]
# Out:
# 0          69
# 1         120
# 2          97
# 3          35
# 4          41
#          ...
# 131619     63
# 131620    109
# 131621     51
# 131622     41
# 131623     31
# Name: Balls Left, Length: 131624, dtype: int64

# %%
dataset["Balls Bowled"] = 120 - dataset["Balls Left"]

# %%
dataset
# Out:
#         Batting Team  Bowling Team          City  Balls Left  Current Score  \
# 0        New Zealand     Sri Lanka       Colombo          51             94
# 1            England  South Africa        Durban           0            204
# 2        New Zealand  South Africa        Durban          23             79
# 3       South Africa   New Zealand    Chattogram          85             39
# 4           Pakistan     Sri Lanka     King City          79             44
# ...              ...           ...           ...         ...            ...
# 131619         India   New Zealand  Johannesburg          57            103
# 131620      Pakistan   New Zealand      Auckland          11            136
# 131621      Zimbabwe  South Africa    Hambantota          69             40
# 131622      Pakistan       England         Dubai          79             37
# 131623         India     Sri Lanka       Colombo          89             46
#
# ...

# %%
dataset.drop(columns=["Balls Left"] , inplace = True)

# %%
dataset
# Out:
#         Batting Team  Bowling Team          City  Current Score  \
# 0        New Zealand     Sri Lanka       Colombo             94
# 1            England  South Africa        Durban            204
# 2        New Zealand  South Africa        Durban             79
# 3       South Africa   New Zealand    Chattogram             39
# 4           Pakistan     Sri Lanka     King City             44
# ...              ...           ...           ...            ...
# 131619         India   New Zealand  Johannesburg            103
# 131620      Pakistan   New Zealand      Auckland            136
# 131621      Zimbabwe  South Africa    Hambantota             40
# 131622      Pakistan       England         Dubai             37
# 131623         India     Sri Lanka       Colombo             46
#
#         Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  \
# 0               8.173913             9            42                 1
# ...

# %%
def balls_to_overs(x):

    balls_bowled = x    #69
    temp = x          #69
    div_by_six = int (temp / 6)  #11.5   ---  11
    mul_by_6  = div_by_six * 6   #66
    temp = (balls_bowled - mul_by_6 )  # 69 - 66 = 3
    temp = temp / 10         #0.3
    overs = div_by_six + temp

    return overs

# %%
 dataset["Overs Completed"] = dataset["Balls Bowled"].apply(balls_to_overs)

# %%
#dataset.drop(columns=["Overs Completed"] , inplace=True)

# %%
dataset
# Out:
#         Batting Team  Bowling Team          City  Current Score  \
# 0        New Zealand     Sri Lanka       Colombo             94
# 1            England  South Africa        Durban            204
# 2        New Zealand  South Africa        Durban             79
# 3       South Africa   New Zealand    Chattogram             39
# 4           Pakistan     Sri Lanka     King City             44
# ...              ...           ...           ...            ...
# 131619         India   New Zealand  Johannesburg            103
# 131620      Pakistan   New Zealand      Auckland            136
# 131621      Zimbabwe  South Africa    Hambantota             40
# 131622      Pakistan       England         Dubai             37
# 131623         India     Sri Lanka       Colombo             46
#
#         Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  \
# 0               8.173913             9            42                 1
# ...

# %%
'''
x = 69
print(x)


balls_bowled = x    #69
print(balls_bowled)


temp = x          #69
print(temp)


div_by_six = temp / 6  #11.5   
print(div_by_six)



div_by_six = int(div_by_six) #11
print(div_by_six)




mul_by_6  = div_by_six * 6   #66
print(mul_by_6)



temp = (balls_bowled - mul_by_6 )  # 69 - 66 = 3
print(temp)



temp = temp / 10         #0.3
print(temp)


overs = div_by_six + temp
overs
'''
# Out:
# '\nx = 69\nprint(x)\n\n\nballs_bowled = x    #69\nprint(balls_bowled)\n\n\ntemp = x          #69\nprint(temp)\n\n\ndiv_by_six = temp / 6  #11.5   \nprint(div_by_six)\n\n\n\ndiv_by_six = int(div_by_six) #11\nprint(div_by_six)\n\n\n\n\nmul_by_6  = div_by_six * 6   #66\nprint(mul_by_6)\n\n\n\ntemp = (balls_bowled - mul_by_6 )  # 69 - 66 = 3\nprint(temp)\n\n\n\ntemp = temp / 10         #0.3\nprint(temp)\n\n\novers = div_by_six + temp\novers\n'

# %%
dataset.drop(columns=["Balls Bowled"] , inplace=True)

# %%
dataset
# Out:
#         Batting Team  Bowling Team          City  Current Score  \
# 0        New Zealand     Sri Lanka       Colombo             94
# 1            England  South Africa        Durban            204
# 2        New Zealand  South Africa        Durban             79
# 3       South Africa   New Zealand    Chattogram             39
# 4           Pakistan     Sri Lanka     King City             44
# ...              ...           ...           ...            ...
# 131619         India   New Zealand  Johannesburg            103
# 131620      Pakistan   New Zealand      Auckland            136
# 131621      Zimbabwe  South Africa    Hambantota             40
# 131622      Pakistan       England         Dubai             37
# 131623         India     Sri Lanka       Colombo             46
#
#         Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  \
# 0               8.173913             9            42                 1
# ...

# %%
dataset.shape
# Out:
# (131624, 11)

# %%
dataset.corr(numeric_only= True)["Final_Score"]
# Out:
# Current Score       0.456999
# Current Run Rate    0.705467
# Wickets Left        0.288851
# Run_In_Last5        0.578403
# Wickets_In_Last5   -0.226601
# innings            -0.224086
# Final_Score         1.000000
# Overs Completed     0.088164
# Name: Final_Score, dtype: float64

# %%
dataset.describe()
# Out:
#        Current Score  Current Run Rate   Wickets Left   Run_In_Last5  \
# count  131624.000000     131624.000000  131624.000000  131624.000000
# mean       91.253563          7.541524       6.651196      37.814206
# std        39.859222          1.766908       2.107944      11.344096
# min         6.000000          1.090909       0.000000       4.000000
# 25%        59.000000          6.322581       5.000000      30.000000
# 50%        87.000000          7.448276       7.000000      37.000000
# 75%       119.000000          8.625000       8.000000      45.000000
# max       278.000000         16.600000      10.000000      90.000000
#
#        Wickets_In_Last5        innings    Final_Score  Overs Completed
# count     131624.000000  131624.000000  131624.000000    131624.000000
# mean           1.480080       1.468433     152.533185        11.898673
# std            1.141234       0.499004      32.752668         4.339789
# ...

# %%
dataset.duplicated().sum()
# Out:
# 282

# %%
dataset.shape
# Out:
# (131624, 11)

# %%
dataset.drop_duplicates().shape
# Out:
# (131342, 11)

# %%
dataset.drop_duplicates(inplace= True)

# %%
dataset.shape
# Out:
# (131342, 11)

# %%
dataset.duplicated().sum()
# Out:
# 0

# %%
dataset.head(1)
# Out:
#   Batting Team Bowling Team     City  Current Score  Current Run Rate  \
# 0  New Zealand    Sri Lanka  Colombo             94          8.173913
#
#    Wickets Left  Run_In_Last5  Wickets_In_Last5  innings  Final_Score  \
# 0             9            42                 1        1          170
#
#    Overs Completed
# 0             11.3

# %%
sns.displot(dataset["Final_Score"])

# %%
x = dataset.drop(columns="Final_Score")
y = dataset["Final_Score"]

# %%
x
# Out:
#         Batting Team  Bowling Team          City  Current Score  \
# 0        New Zealand     Sri Lanka       Colombo             94
# 1            England  South Africa        Durban            204
# 2        New Zealand  South Africa        Durban             79
# 3       South Africa   New Zealand    Chattogram             39
# 4           Pakistan     Sri Lanka     King City             44
# ...              ...           ...           ...            ...
# 131619         India   New Zealand  Johannesburg            103
# 131620      Pakistan   New Zealand      Auckland            136
# 131621      Zimbabwe  South Africa    Hambantota             40
# 131622      Pakistan       England         Dubai             37
# 131623         India     Sri Lanka       Colombo             46
#
#         Current Run Rate  Wickets Left  Run_In_Last5  Wickets_In_Last5  \
# 0               8.173913             9            42                 1
# ...

# %%
y
# Out:
# 0         170
# 1         204
# 2          86
# 3         170
# 4         141
#          ...
# 131619    180
# 131620    153
# 131621     93
# 131622    146
# 131623    174
# Name: Final_Score, Length: 131342, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size= 0.2 , random_state=42)

# %%
x_train.shape
# Out:
# (105073, 10)

# %%
x_test.shape
# Out:
# (26269, 10)

# %%
y_train.shape
# Out:
# (105073,)

# %%
y_test.shape
# Out:
# (26269,)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder , StandardScaler
from sklearn.metrics import r2_score,mean_absolute_error , accuracy_score

# %%
from sklearn.linear_model import LinearRegression,Ridge,Lasso , LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,GradientBoostingRegressor,AdaBoostRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %%
ct = ColumnTransformer ( transformers= [("Col trans" , OneHotEncoder ( sparse_output= False , drop = "first"),
                                          [0,1,2])] , remainder= "passthrough"
                          )

# %%
knn= KNeighborsRegressor (n_neighbors=2)

pipe = Pipeline ([
    ("step1" , ct),
    ("step2",StandardScaler()),
    ("step3" , knn)
])

# %%
pipe.fit (x_train , y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Col trans',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   [0, 1, 2])])),
#                 ('step2', StandardScaler()),
#                 ('step3', KNeighborsRegressor(n_neighbors=2))])

# %%
y_predict = pipe.predict (x_test)

# %%
print ("R2_SCORE" , r2_score (y_test , y_predict))
print ("MAE" , mean_absolute_error (y_test , y_predict))
# Out:
# R2_SCORE 0.9967692978649404
# MAE 0.1493204918344817

# %%
import pickle 

pickle.dump (dataset , open ("T20_dataset.pkl" , "wb"))
pickle.dump (pipe , open ("t20_pipe.pkl" , "wb"))

# %%
#crr

# %%
94
11.3
# Out:
# 11.3

# %%
runs = 94
overs = 11.3

overs_dec = overs - int(overs)
print(overs_dec)

x = overs_dec * 10
print(x)

y = x * 1.66
print(y)

z= y / 10
print(z)


overs = int(overs) + z
print(overs)

crr = runs / overs
print(crr)
# Out:
# 0.3000000000000007
# 3.000000000000007
# 4.980000000000012
# 0.4980000000000012
# 11.498000000000001
# 8.175334840841884
